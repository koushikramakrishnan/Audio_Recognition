# %% [markdown]
# ### Load Preprocessed data

# %%
# retrieve the preprocessed data from previous notebook

# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               10496
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 78,858
# Trainable params: 78,858
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 11.6772%

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/100
# 6985/6985 [==============================] - 4s 591us/step - loss: 9.1031 - accuracy: 0.1800 - val_loss: 2.1876 - val_accuracy: 0.1780
#
# Epoch 00001: val_loss improved from inf to 2.18759, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 6985/6985 [==============================] - 3s 385us/step - loss: 2.2881 - accuracy: 0.2192 - val_loss: 2.0307 - val_accuracy: 0.3211
#
# Epoch 00002: val_loss improved from 2.18759 to 2.03075, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 3/100
# 6985/6985 [==============================] - 3s 411us/step - loss: 2.0730 - accuracy: 0.2551 - val_loss: 1.9175 - val_accuracy: 0.3618
#
# Epoch 00003: val_loss improved from 2.03075 to 1.91746, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 4/100
# 6985/6985 [==============================] - 3s 394us/step - loss: 1.9887 - accuracy: 0.2805 - val_loss: 1.7777 - val_accuracy: 0.3463
#
# Epoch 00004: val_loss improved from 1.91746 to 1.77767, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 5/100
# 6985/6985 [==============================] - 3s 404us/step - loss: 1.8863 - accuracy: 0.3230 - val_loss: 1.6935 - val_accuracy: 0.4035
#
# Epoch 00005: val_loss improved from 1.77767 to 1.69347, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 6/100
# 6985/6985 [==============================] - 3s 416us/step - loss: 1.8190 - accuracy: 0.3433 - val_loss: 1.6109 - val_accuracy: 0.4156
#
# Epoch 00006: val_loss improved from 1.69347 to 1.61085, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 7/100
# 6985/6985 [==============================] - 3s 420us/step - loss: 1.7277 - accuracy: 0.3814 - val_loss: 1.5135 - val_accuracy: 0.4934
#
# Epoch 00007: val_loss improved from 1.61085 to 1.51349, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 8/100
# 6985/6985 [==============================] - 3s 404us/step - loss: 1.6387 - accuracy: 0.4289 - val_loss: 1.3940 - val_accuracy: 0.5644
#
# Epoch 00008: val_loss improved from 1.51349 to 1.39404, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 9/100
# 6985/6985 [==============================] - 3s 422us/step - loss: 1.5530 - accuracy: 0.4627 - val_loss: 1.3187 - val_accuracy: 0.5598
#
# Epoch 00009: val_loss improved from 1.39404 to 1.31867, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 10/100
# 6985/6985 [==============================] - 3s 421us/step - loss: 1.4734 - accuracy: 0.4926 - val_loss: 1.2431 - val_accuracy: 0.6005
#
# Epoch 00010: val_loss improved from 1.31867 to 1.24308, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 11/100
# 6985/6985 [==============================] - 3s 396us/step - loss: 1.3801 - accuracy: 0.5254 - val_loss: 1.1618 - val_accuracy: 0.6222
#
# Epoch 00011: val_loss improved from 1.24308 to 1.16175, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 12/100
# 6985/6985 [==============================] - 3s 423us/step - loss: 1.3269 - accuracy: 0.5505 - val_loss: 1.0967 - val_accuracy: 0.6514
#
# Epoch 00012: val_loss improved from 1.16175 to 1.09672, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 13/100
# 6985/6985 [==============================] - 3s 445us/step - loss: 1.2849 - accuracy: 0.5672 - val_loss: 1.0365 - val_accuracy: 0.6795
#
# Epoch 00013: val_loss improved from 1.09672 to 1.03646, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 14/100
# 6985/6985 [==============================] - 3s 396us/step - loss: 1.2230 - accuracy: 0.5757 - val_loss: 1.0116 - val_accuracy: 0.6812
#
# Epoch 00014: val_loss improved from 1.03646 to 1.01159, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 15/100
# 6985/6985 [==============================] - 3s 426us/step - loss: 1.1878 - accuracy: 0.5990 - val_loss: 0.9665 - val_accuracy: 0.6880
#
# Epoch 00015: val_loss improved from 1.01159 to 0.96652, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 16/100
# 6985/6985 [==============================] - 3s 426us/step - loss: 1.1419 - accuracy: 0.6099 - val_loss: 0.8942 - val_accuracy: 0.7184
#
# Epoch 00016: val_loss improved from 0.96652 to 0.89424, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 17/100
# 6985/6985 [==============================] - 3s 409us/step - loss: 1.0888 - accuracy: 0.6306 - val_loss: 0.8582 - val_accuracy: 0.7212
#
# Epoch 00017: val_loss improved from 0.89424 to 0.85816, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 18/100
# 6985/6985 [==============================] - 3s 425us/step - loss: 1.0572 - accuracy: 0.6398 - val_loss: 0.8381 - val_accuracy: 0.7344
#
# Epoch 00018: val_loss improved from 0.85816 to 0.83810, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 19/100
# 6985/6985 [==============================] - 3s 423us/step - loss: 1.0130 - accuracy: 0.6508 - val_loss: 0.7937 - val_accuracy: 0.7504
#
# Epoch 00019: val_loss improved from 0.83810 to 0.79370, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 20/100
# 6985/6985 [==============================] - 3s 447us/step - loss: 1.0053 - accuracy: 0.6571 - val_loss: 0.7821 - val_accuracy: 0.7533
#
# Epoch 00020: val_loss improved from 0.79370 to 0.78208, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 21/100
# 6985/6985 [==============================] - 3s 407us/step - loss: 0.9919 - accuracy: 0.6584 - val_loss: 0.7497 - val_accuracy: 0.7710
#
# Epoch 00021: val_loss improved from 0.78208 to 0.74971, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 22/100
# 6985/6985 [==============================] - 3s 409us/step - loss: 0.9494 - accuracy: 0.6746 - val_loss: 0.7088 - val_accuracy: 0.7808
#
# Epoch 00022: val_loss improved from 0.74971 to 0.70885, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 23/100
# 6985/6985 [==============================] - 3s 427us/step - loss: 0.9059 - accuracy: 0.6905 - val_loss: 0.6886 - val_accuracy: 0.7722
#
# Epoch 00023: val_loss improved from 0.70885 to 0.68862, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 24/100
# 6985/6985 [==============================] - 3s 439us/step - loss: 0.9014 - accuracy: 0.6936 - val_loss: 0.6769 - val_accuracy: 0.7974
#
# Epoch 00024: val_loss improved from 0.68862 to 0.67693, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 25/100
# 6985/6985 [==============================] - 3s 416us/step - loss: 0.8937 - accuracy: 0.7005 - val_loss: 0.6838 - val_accuracy: 0.7894
#
# Epoch 00025: val_loss did not improve from 0.67693
# Epoch 26/100
# 6985/6985 [==============================] - 3s 423us/step - loss: 0.8594 - accuracy: 0.7101 - val_loss: 0.6856 - val_accuracy: 0.7831
#
# Epoch 00026: val_loss did not improve from 0.67693
# Epoch 27/100
# 6985/6985 [==============================] - 3s 423us/step - loss: 0.8560 - accuracy: 0.7130 - val_loss: 0.6397 - val_accuracy: 0.8025
#
# Epoch 00027: val_loss improved from 0.67693 to 0.63974, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 28/100
# 6985/6985 [==============================] - 3s 431us/step - loss: 0.8371 - accuracy: 0.7164 - val_loss: 0.6399 - val_accuracy: 0.8037ra - ETA: 0s - loss: 0.8347 - accuracy: 0.71
#
# Epoch 00028: val_loss did not improve from 0.63974
# Epoch 29/100
# 6985/6985 [==============================] - 3s 440us/step - loss: 0.8152 - accuracy: 0.7211 - val_loss: 0.6243 - val_accuracy: 0.8134
#
# Epoch 00029: val_loss improved from 0.63974 to 0.62433, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 30/100
# 6985/6985 [==============================] - 3s 409us/step - loss: 0.8056 - accuracy: 0.7280 - val_loss: 0.6319 - val_accuracy: 0.8088
#
# Epoch 00030: val_loss did not improve from 0.62433
# Epoch 31/100
# 6985/6985 [==============================] - 3s 423us/step - loss: 0.7845 - accuracy: 0.7306 - val_loss: 0.6153 - val_accuracy: 0.7968
#
# Epoch 00031: val_loss improved from 0.62433 to 0.61532, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 32/100
# 6985/6985 [==============================] - 3s 431us/step - loss: 0.8053 - accuracy: 0.7310 - val_loss: 0.6028 - val_accuracy: 0.8226
#
# Epoch 00032: val_loss improved from 0.61532 to 0.60284, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 33/100
# 6985/6985 [==============================] - 3s 387us/step - loss: 0.7877 - accuracy: 0.7256 - val_loss: 0.5859 - val_accuracy: 0.8208
#
# Epoch 00033: val_loss improved from 0.60284 to 0.58587, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 34/100
# 6985/6985 [==============================] - 3s 388us/step - loss: 0.7775 - accuracy: 0.7350 - val_loss: 0.5591 - val_accuracy: 0.8380
#
# Epoch 00034: val_loss improved from 0.58587 to 0.55906, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 35/100
# 6985/6985 [==============================] - 3s 392us/step - loss: 0.7567 - accuracy: 0.7449 - val_loss: 0.5474 - val_accuracy: 0.8334
#
# Epoch 00035: val_loss improved from 0.55906 to 0.54738, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 36/100
# 6985/6985 [==============================] - 3s 366us/step - loss: 0.7448 - accuracy: 0.7407 - val_loss: 0.5492 - val_accuracy: 0.8420
#
# Epoch 00036: val_loss did not improve from 0.54738
# Epoch 37/100
# 6985/6985 [==============================] - 3s 379us/step - loss: 0.7252 - accuracy: 0.7563 - val_loss: 0.5305 - val_accuracy: 0.8403
#
# Epoch 00037: val_loss improved from 0.54738 to 0.53046, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 38/100
# 6985/6985 [==============================] - 3s 395us/step - loss: 0.7123 - accuracy: 0.7532 - val_loss: 0.5462 - val_accuracy: 0.8317
#
# Epoch 00038: val_loss did not improve from 0.53046
# Epoch 39/100
# 6985/6985 [==============================] - 3s 389us/step - loss: 0.7057 - accuracy: 0.7542 - val_loss: 0.5366 - val_accuracy: 0.8426
#
# Epoch 00039: val_loss did not improve from 0.53046
# Epoch 40/100
# 6985/6985 [==============================] - 3s 387us/step - loss: 0.7035 - accuracy: 0.7618 - val_loss: 0.5210 - val_accuracy: 0.8409
#
# Epoch 00040: val_loss improved from 0.53046 to 0.52098, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 41/100
# 6985/6985 [==============================] - 3s 411us/step - loss: 0.7007 - accuracy: 0.7598 - val_loss: 0.5366 - val_accuracy: 0.8334
#
# Epoch 00041: val_loss did not improve from 0.52098
# Epoch 42/100
# 6985/6985 [==============================] - 3s 381us/step - loss: 0.6872 - accuracy: 0.7676 - val_loss: 0.5034 - val_accuracy: 0.8489
#
# Epoch 00042: val_loss improved from 0.52098 to 0.50343, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 43/100
# 6985/6985 [==============================] - 3s 393us/step - loss: 0.6964 - accuracy: 0.7654 - val_loss: 0.5040 - val_accuracy: 0.8397
#
# Epoch 00043: val_loss did not improve from 0.50343
# Epoch 44/100
# 6985/6985 [==============================] - 3s 388us/step - loss: 0.6721 - accuracy: 0.7729 - val_loss: 0.5178 - val_accuracy: 0.8380
#
# Epoch 00044: val_loss did not improve from 0.50343
# Epoch 45/100
# 6985/6985 [==============================] - 3s 389us/step - loss: 0.6673 - accuracy: 0.7774 - val_loss: 0.4842 - val_accuracy: 0.8546
#
# Epoch 00045: val_loss improved from 0.50343 to 0.48420, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 46/100
# 6985/6985 [==============================] - 3s 376us/step - loss: 0.6708 - accuracy: 0.7672 - val_loss: 0.5145 - val_accuracy: 0.8300
#
# Epoch 00046: val_loss did not improve from 0.48420
# Epoch 47/100
# 6985/6985 [==============================] - 3s 391us/step - loss: 0.6456 - accuracy: 0.7761 - val_loss: 0.4842 - val_accuracy: 0.8609
#
# Epoch 00047: val_loss improved from 0.48420 to 0.48415, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 48/100
# 6985/6985 [==============================] - 3s 388us/step - loss: 0.6370 - accuracy: 0.7834 - val_loss: 0.4919 - val_accuracy: 0.8512
#
# Epoch 00048: val_loss did not improve from 0.48415
# Epoch 49/100
# 6985/6985 [==============================] - 3s 398us/step - loss: 0.6282 - accuracy: 0.7907 - val_loss: 0.4901 - val_accuracy: 0.8626
#
# Epoch 00049: val_loss did not improve from 0.48415
# Epoch 50/100
# 6985/6985 [==============================] - 3s 387us/step - loss: 0.6273 - accuracy: 0.7881 - val_loss: 0.4663 - val_accuracy: 0.8603
#
# Epoch 00050: val_loss improved from 0.48415 to 0.46628, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 51/100
# 6985/6985 [==============================] - 3s 369us/step - loss: 0.6077 - accuracy: 0.7953 - val_loss: 0.4639 - val_accuracy: 0.8620
#
# Epoch 00051: val_loss improved from 0.46628 to 0.46392, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 52/100
# 6985/6985 [==============================] - 3s 399us/step - loss: 0.6251 - accuracy: 0.7832 - val_loss: 0.4786 - val_accuracy: 0.8592
#
# Epoch 00052: val_loss did not improve from 0.46392
# Epoch 53/100
# 6985/6985 [==============================] - 3s 384us/step - loss: 0.6248 - accuracy: 0.7891 - val_loss: 0.4873 - val_accuracy: 0.8546
#
# Epoch 00053: val_loss did not improve from 0.46392
# Epoch 54/100
# 6985/6985 [==============================] - 3s 424us/step - loss: 0.6311 - accuracy: 0.7817 - val_loss: 0.4828 - val_accuracy: 0.8580
#
# Epoch 00054: val_loss did not improve from 0.46392
# Epoch 55/100
# 6985/6985 [==============================] - 3s 379us/step - loss: 0.6049 - accuracy: 0.7954 - val_loss: 0.4797 - val_accuracy: 0.8535
#
# Epoch 00055: val_loss did not improve from 0.46392
# Epoch 56/100
# 6985/6985 [==============================] - 3s 410us/step - loss: 0.6248 - accuracy: 0.7847 - val_loss: 0.4708 - val_accuracy: 0.8512
#
# Epoch 00056: val_loss did not improve from 0.46392
# Epoch 57/100
# 6985/6985 [==============================] - 3s 442us/step - loss: 0.6224 - accuracy: 0.7875 - val_loss: 0.4554 - val_accuracy: 0.8620
#
# Epoch 00057: val_loss improved from 0.46392 to 0.45538, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 58/100
# 6985/6985 [==============================] - 3s 397us/step - loss: 0.5851 - accuracy: 0.8027 - val_loss: 0.4686 - val_accuracy: 0.8592
#
# Epoch 00058: val_loss did not improve from 0.45538
# Epoch 59/100
# 6985/6985 [==============================] - 2s 358us/step - loss: 0.6006 - accuracy: 0.7934 - val_loss: 0.4482 - val_accuracy: 0.8632
#
# Epoch 00059: val_loss improved from 0.45538 to 0.44819, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 60/100
# 6985/6985 [==============================] - 3s 389us/step - loss: 0.5860 - accuracy: 0.7967 - val_loss: 0.4716 - val_accuracy: 0.8563
#
# Epoch 00060: val_loss did not improve from 0.44819
# Epoch 61/100
# 6985/6985 [==============================] - 3s 416us/step - loss: 0.5791 - accuracy: 0.8019 - val_loss: 0.4447 - val_accuracy: 0.8661
#
# Epoch 00061: val_loss improved from 0.44819 to 0.44469, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 62/100
# 6985/6985 [==============================] - 3s 424us/step - loss: 0.5731 - accuracy: 0.8006 - val_loss: 0.4552 - val_accuracy: 0.8643
#
# Epoch 00062: val_loss did not improve from 0.44469
# Epoch 63/100
# 6985/6985 [==============================] - 3s 393us/step - loss: 0.5932 - accuracy: 0.7970 - val_loss: 0.4433 - val_accuracy: 0.8626
#
# Epoch 00063: val_loss improved from 0.44469 to 0.44328, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 64/100
# 6985/6985 [==============================] - 3s 414us/step - loss: 0.5808 - accuracy: 0.8016 - val_loss: 0.4611 - val_accuracy: 0.8666
#
# Epoch 00064: val_loss did not improve from 0.44328
# Epoch 65/100
# 6985/6985 [==============================] - 3s 420us/step - loss: 0.5822 - accuracy: 0.8036 - val_loss: 0.4468 - val_accuracy: 0.8706
#
# Epoch 00065: val_loss did not improve from 0.44328
# Epoch 66/100
# 6985/6985 [==============================] - 3s 400us/step - loss: 0.5735 - accuracy: 0.8049 - val_loss: 0.4360 - val_accuracy: 0.8741
#
# Epoch 00066: val_loss improved from 0.44328 to 0.43605, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 67/100
# 6985/6985 [==============================] - 3s 402us/step - loss: 0.5995 - accuracy: 0.7966 - val_loss: 0.4432 - val_accuracy: 0.8741
#
# Epoch 00067: val_loss did not improve from 0.43605
# Epoch 68/100
# 6985/6985 [==============================] - 3s 406us/step - loss: 0.5710 - accuracy: 0.8094 - val_loss: 0.4489 - val_accuracy: 0.8678
#
# Epoch 00068: val_loss did not improve from 0.43605
# Epoch 69/100
# 6985/6985 [==============================] - 3s 390us/step - loss: 0.5672 - accuracy: 0.8097 - val_loss: 0.4388 - val_accuracy: 0.8706
#
# Epoch 00069: val_loss did not improve from 0.43605
# Epoch 70/100
# 6985/6985 [==============================] - 3s 396us/step - loss: 0.5713 - accuracy: 0.8116 - val_loss: 0.4434 - val_accuracy: 0.8678
#
# Epoch 00070: val_loss did not improve from 0.43605
# Epoch 71/100
# 6985/6985 [==============================] - 3s 377us/step - loss: 0.5798 - accuracy: 0.8064 - val_loss: 0.4511 - val_accuracy: 0.8661
#
# Epoch 00071: val_loss did not improve from 0.43605
# Epoch 72/100
# 6985/6985 [==============================] - 3s 391us/step - loss: 0.5735 - accuracy: 0.7987 - val_loss: 0.4430 - val_accuracy: 0.8741
#
# Epoch 00072: val_loss did not improve from 0.43605
# Epoch 73/100
# 6985/6985 [==============================] - 3s 371us/step - loss: 0.5801 - accuracy: 0.8099 - val_loss: 0.4664 - val_accuracy: 0.8546
#
# Epoch 00073: val_loss did not improve from 0.43605
# Epoch 74/100
# 6985/6985 [==============================] - 3s 386us/step - loss: 0.5749 - accuracy: 0.8067 - val_loss: 0.4297 - val_accuracy: 0.8798
#
# Epoch 00074: val_loss improved from 0.43605 to 0.42975, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 75/100
# 6985/6985 [==============================] - 3s 388us/step - loss: 0.5431 - accuracy: 0.8142 - val_loss: 0.4514 - val_accuracy: 0.8638
#
# Epoch 00075: val_loss did not improve from 0.42975
# Epoch 76/100
# 6985/6985 [==============================] - 3s 395us/step - loss: 0.5323 - accuracy: 0.8180 - val_loss: 0.4324 - val_accuracy: 0.8758
#
# Epoch 00076: val_loss did not improve from 0.42975
# Epoch 77/100
# 6985/6985 [==============================] - 3s 403us/step - loss: 0.5461 - accuracy: 0.8186 - val_loss: 0.4363 - val_accuracy: 0.8701
#
# Epoch 00077: val_loss did not improve from 0.42975
# Epoch 78/100
# 6985/6985 [==============================] - 3s 375us/step - loss: 0.5400 - accuracy: 0.8157 - val_loss: 0.4623 - val_accuracy: 0.8689
#
# Epoch 00078: val_loss did not improve from 0.42975
# Epoch 79/100
# 6985/6985 [==============================] - 3s 410us/step - loss: 0.5751 - accuracy: 0.8096 - val_loss: 0.4716 - val_accuracy: 0.8598
#
# Epoch 00079: val_loss did not improve from 0.42975
# Epoch 80/100
# 6985/6985 [==============================] - 3s 379us/step - loss: 0.5621 - accuracy: 0.8115 - val_loss: 0.4341 - val_accuracy: 0.8689
#
# Epoch 00080: val_loss did not improve from 0.42975
# Epoch 81/100
# 6985/6985 [==============================] - 3s 399us/step - loss: 0.5284 - accuracy: 0.8215 - val_loss: 0.4433 - val_accuracy: 0.8661
#
# Epoch 00081: val_loss did not improve from 0.42975
# Epoch 82/100
# 6985/6985 [==============================] - 3s 431us/step - loss: 0.5445 - accuracy: 0.8173 - val_loss: 0.4335 - val_accuracy: 0.8804
#
# Epoch 00082: val_loss did not improve from 0.42975
# Epoch 83/100
# 6985/6985 [==============================] - 3s 434us/step - loss: 0.5454 - accuracy: 0.8200 - val_loss: 0.4339 - val_accuracy: 0.8724 loss: 0
#
# Epoch 00083: val_loss did not improve from 0.42975
# Epoch 84/100
# 6985/6985 [==============================] - 3s 465us/step - loss: 0.5263 - accuracy: 0.8226 - val_loss: 0.4424 - val_accuracy: 0.8666
#
# Epoch 00084: val_loss did not improve from 0.42975
# Epoch 85/100
# 6985/6985 [==============================] - 3s 434us/step - loss: 0.5242 - accuracy: 0.8239 - val_loss: 0.4185 - val_accuracy: 0.8724
#
# Epoch 00085: val_loss improved from 0.42975 to 0.41852, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 86/100
# 6985/6985 [==============================] - 3s 414us/step - loss: 0.5272 - accuracy: 0.8183 - val_loss: 0.4313 - val_accuracy: 0.8735
#
# Epoch 00086: val_loss did not improve from 0.41852
# Epoch 87/100
# 6985/6985 [==============================] - 3s 417us/step - loss: 0.5382 - accuracy: 0.8218 - val_loss: 0.4493 - val_accuracy: 0.8672
#
# Epoch 00087: val_loss did not improve from 0.41852
# Epoch 88/100
# 6985/6985 [==============================] - 3s 421us/step - loss: 0.5395 - accuracy: 0.8202 - val_loss: 0.4167 - val_accuracy: 0.8735
#
# Epoch 00088: val_loss improved from 0.41852 to 0.41666, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 89/100
# 6985/6985 [==============================] - 3s 420us/step - loss: 0.5299 - accuracy: 0.8193 - val_loss: 0.4209 - val_accuracy: 0.8815
#
# Epoch 00089: val_loss did not improve from 0.41666
# Epoch 90/100
# 6985/6985 [==============================] - 3s 431us/step - loss: 0.5302 - accuracy: 0.8216 - val_loss: 0.4161 - val_accuracy: 0.8752
#
# Epoch 00090: val_loss improved from 0.41666 to 0.41614, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 91/100
# 6985/6985 [==============================] - 3s 424us/step - loss: 0.5263 - accuracy: 0.8232 - val_loss: 0.4203 - val_accuracy: 0.8872
#
# Epoch 00091: val_loss did not improve from 0.41614
# Epoch 92/100
# 6985/6985 [==============================] - 3s 425us/step - loss: 0.5317 - accuracy: 0.8216 - val_loss: 0.4423 - val_accuracy: 0.8798
#
# Epoch 00092: val_loss did not improve from 0.41614
# Epoch 93/100
# 6985/6985 [==============================] - 3s 411us/step - loss: 0.5286 - accuracy: 0.8233 - val_loss: 0.4077 - val_accuracy: 0.8804
#
# Epoch 00093: val_loss improved from 0.41614 to 0.40769, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 94/100
# 6985/6985 [==============================] - 3s 421us/step - loss: 0.5185 - accuracy: 0.8286 - val_loss: 0.4179 - val_accuracy: 0.8718
#
# Epoch 00094: val_loss did not improve from 0.40769
# Epoch 95/100
# 6985/6985 [==============================] - 3s 400us/step - loss: 0.5199 - accuracy: 0.8272 - val_loss: 0.4148 - val_accuracy: 0.8764
#
# Epoch 00095: val_loss did not improve from 0.40769
# Epoch 96/100
# 6985/6985 [==============================] - 3s 427us/step - loss: 0.5199 - accuracy: 0.8293 - val_loss: 0.4152 - val_accuracy: 0.8821
#
# Epoch 00096: val_loss did not improve from 0.40769
# Epoch 97/100
# 6985/6985 [==============================] - 3s 413us/step - loss: 0.5151 - accuracy: 0.8261 - val_loss: 0.4223 - val_accuracy: 0.8752
#
# Epoch 00097: val_loss did not improve from 0.40769
# Epoch 98/100
# 6985/6985 [==============================] - 3s 395us/step - loss: 0.5016 - accuracy: 0.8338 - val_loss: 0.4201 - val_accuracy: 0.8878
#
# Epoch 00098: val_loss did not improve from 0.40769
# Epoch 99/100
# 6985/6985 [==============================] - 3s 422us/step - loss: 0.5303 - accuracy: 0.8226 - val_loss: 0.4037 - val_accuracy: 0.8775
#
# Epoch 00099: val_loss improved from 0.40769 to 0.40372, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 100/100
# 6985/6985 [==============================] - 3s 409us/step - loss: 0.5115 - accuracy: 0.8288 - val_loss: 0.3994 - val_accuracy: 0.8821 0.4902 - accuracy - ETA: 0s -
#
# Epoch 00100: val_loss improved from 0.40372 to 0.39942, saving model to saved_models/weights.best.basic_mlp.hdf5
# Training completed in time:  0:04:56.089980

# %%
# Evaluating the model on the training and testing set
model.save('C:/Users/Koushik/Desktop/Audio Recognition/model_final.h5')
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9235504865646362
# Testing Accuracy:  0.8820835947990417

# %%
import librosa 
import numpy as np 

def extract_feature(file_name):
   
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None

    return np.array([mfccsscaled])

# %%
def print_prediction(file_name):
    prediction_feature = extract_feature(file_name) 

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
# Class: Air Conditioner

filename = '../UrbanSound Dataset sample/audio/100852-0-0-0.wav' 
print_prediction(filename)
# Out:
# The predicted class is: air_conditioner
#
# air_conditioner 		 :  0.99856996536254882812500000000000
# car_horn 		 :  0.00000308554490402457304298877716
# children_playing 		 :  0.00082344195106998085975646972656
# dog_bark 		 :  0.00006271887832554057240486145020
# drilling 		 :  0.00010769975051516667008399963379
# engine_idling 		 :  0.00005196390702622011303901672363
# gun_shot 		 :  0.00000081253705275230458937585354
# jackhammer 		 :  0.00023298669839277863502502441406
# siren 		 :  0.00000084156761204212671145796776
# street_music 		 :  0.00014636160631198436021804809570

# %%
# Class: Drilling

filename = '../UrbanSound Dataset sample/audio/103199-4-0-0.wav'
print_prediction(filename)
# Out:
# The predicted class is: drilling
#
# air_conditioner 		 :  0.00000000000197462272227832968952
# car_horn 		 :  0.00000002670304688479063770500943
# children_playing 		 :  0.00000052972393405070761218667030
# dog_bark 		 :  0.00000480298376714927144348621368
# drilling 		 :  0.99582004547119140625000000000000
# engine_idling 		 :  0.00000000007164942944504204547229
# gun_shot 		 :  0.00000003148903360283838992472738
# jackhammer 		 :  0.00000000439228564630411710822955
# siren 		 :  0.00000000920122378289534026407637
# street_music 		 :  0.00417456682771444320678710937500

# %%
filename = '../UrbanSound Dataset sample/audio/100852-0-0-0.wav' 
print_prediction(filename)
# Out:
# The predicted class is: air_conditioner
#
# air_conditioner 		 :  0.99996960163116455078125000000000
# car_horn 		 :  0.00000230791738431435078382492065
# children_playing 		 :  0.00000146936793044005753472447395
# dog_bark 		 :  0.00000011662591958838675054721534
# drilling 		 :  0.00001006040110951289534568786621
# engine_idling 		 :  0.00000969923530647065490484237671
# gun_shot 		 :  0.00000017488534354015428107231855
# jackhammer 		 :  0.00000410210759582696482539176941
# siren 		 :  0.00000003429158823564648628234863
# street_music 		 :  0.00000269578549705329351127147675

# %%
filename = '../UrbanSound Dataset sample/audio/100852-0-0-0.wav' 
print_prediction(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c29cdfc23dd7> in <module>
#       1 filename = '../UrbanSound Dataset sample/audio/100852-0-0-0.wav'
# ----> 2 print_prediction(filename)
#
# <ipython-input-3-7d829c4135ac> in print_prediction(file_name)
#       2     prediction_feature = extract_feature(file_name)
#       3
# ----> 4     predicted_vector = model.predict_classes(prediction_feature)
#       5     predicted_class = le.inverse_transform(predicted_vector)
#       6     print("The predicted class is:", predicted_class[0], '\n')
#
# NameError: name 'model' is not defined
